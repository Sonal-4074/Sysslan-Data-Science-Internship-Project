# %%
import pandas as pd

# Load dataset
df = pd.read_csv("Dataset1.csv")

# %%
# Before cleaning

print("Before Cleaning:")
print("Total Records:", len(df))

print("\nMissing Values:")
print(df.isnull().sum())

print("\nDuplicate Records:")
print(df.duplicated().sum())
# Out:
# Before Cleaning:
# Total Records: 186074
#
# Missing Values:
# SN                0
# Train_No          0
# Station_Code      0
# 1A                0
# 2A                0
# 3A                0
# SL                0
# Station_Name      0
# Route_Number      0
# Arrival_time      0
# Departure_Time    0
# Distance          0
# dtype: int64
#
# Duplicate Records:
# 0

# %%
# Fill missing arrival/departure time
df['Arrival_time'] = df['Arrival_time'].fillna("Unknown")
df['Departure_Time'] = df['Departure_Time'].fillna("Unknown")

# %%
# Fill missing numeric values
df['Distance'] = df['Distance'].fillna(df['Distance'].mean())

# %%
# Remove duplicate records

df = df.drop_duplicates()

# %%
# After cleaning

print("\nAfter Cleaning:")
print("Total Records:", len(df))

print("\nMissing Values:")
print(df.isnull().sum())

print("\nDuplicate Records:")
print(df.duplicated().sum())
# Out:
# After Cleaning:
# Total Records: 186074
#
# Missing Values:
# SN                0
# Train_No          0
# Station_Code      0
# 1A                0
# 2A                0
# 3A                0
# SL                0
# Station_Name      0
# Route_Number      0
# Arrival_time      0
# Departure_Time    0
# Distance          0
# dtype: int64
#
# Duplicate Records:
# 0

# %%
# Save cleaned dataset
df.to_csv("Cleaned_Dataset.csv", index=False)
